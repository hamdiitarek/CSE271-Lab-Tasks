# %% [markdown]
# Part 1

# %%
import matplotlib.pyplot as plt

Brands = ['Audi', 'BMW', 'Cadilac', 'Dodge', 'Ford']
Monthy_Sale = [43, 34, 87, 76, 105]

fig, ax = plt.subplots()
ax.pie(Monthy_Sale, labels=Brands, autopct='%1.1f%%')
ax.set_title('Car Sales Last Month')
# Out:
# Text(0.5, 1.0, 'Car Sales Last Month')

# %%
import matplotlib.pyplot as plt

Brands = ['Audi', 'BMW', 'Cadilac', 'Dodge', 'Ford']
Monthy_Sale = [43, 34, 87, 76, 105]

fig, ax = plt.subplots()
ax.pie(Monthy_Sale, labels=Brands, autopct='%1.1f%%')
ax.set_title('Car Sales Last Month')
